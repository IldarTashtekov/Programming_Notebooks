# %%
import os
# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 3.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path_compressed_file = '/content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/dataset.rar'
path_extraction = '/content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/'  
Archive(path_compressed_file).extractall(path_extraction)

# %%
# !git clone https://github.com/WongKinYiu/yolov7  # clone

# %%
# !pip install -r /content/yolov7/requirements.txt  # install

# %%
# !cp /content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/yolov7.pt /content/yolov7/
# !cp  /content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/dataset.yaml /content/yolov7/data/
# !cp /content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/yolov7-custom.yaml /content/yolov7/cfg/training/

# %%
# %cd yolov7/

# %%
# !python train.py --device 0 --batch-size 16 --epochs 100 --img 640 640 --data data/dataset.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt
# Out:
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7-custom.yaml', data='data/dataset.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp9', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python /content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/yolov7/detect.py --weights /content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/yolov7/runs/train/exp9/weights/best.pt --conf 0.5 --img-size 640 --source /content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/dataset/test/images/imgs310.jpg --no-trace
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=True, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/dataset/test/images/imgs310.jpg', update=False, view_img=False, weights=['/content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/yolov7/runs/train/exp9/weights/best.pt'])
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# fatal: not a git repository (or any of the parent directories): .git
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/yolov7/utils/google_utils.py", line 26, in attempt_download
#     assets = [x['name'] for x in response['assets']]  # release assets
# KeyError: 'assets'
#
# ...

# %%
# !mv /content/yolov7 /content/drive/MyDrive/Colab_Notebooks/Miscelanea_Notebooks/COWS_DETECTOR_YOLO/
